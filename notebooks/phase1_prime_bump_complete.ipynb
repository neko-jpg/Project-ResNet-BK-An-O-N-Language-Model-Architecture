# %% [markdown]
# # Phase1 prime-bump A/B (auto-compare)
# Clone → install → baseline train → prime-bump train → summarize loss/PPL from logs.
# Any command fails ⇒ raises.

# %%
import subprocess, pathlib, sys
repo_url = "https://github.com/neko-jpg/Project-ResNet-BK-An-O-N-Language-Model-Architecture.git"
cwd = pathlib.Path('.').resolve()
if (cwd / '.git').exists():
    repo_root = cwd
else:
    repo_root = cwd / 'Project-ResNet-BK-An-O-N-Language-Model-Architecture'
    if not repo_root.exists():
        print(f'Cloning {repo_url} into {repo_root} ...')
        subprocess.run(['git', 'clone', repo_url, str(repo_root)], check=True)
    else:
        print(f'Using existing clone at {repo_root}')
print('Repo root:', repo_root)

# %%
import subprocess, sys
print('Installing requirements...')
res = subprocess.run([sys.executable, '-m', 'pip', 'install', '-r', 'requirements.txt'], cwd=repo_root, check=False)
print('returncode', res.returncode)
assert res.returncode == 0, 'pip install failed'

# %%
import subprocess, sys
baseline_dir = repo_root / 'checkpoints' / 'baseline'
baseline_dir.mkdir(parents=True, exist_ok=True)
cmd = [sys.executable, 'train.py', '--config-preset', 'baseline', '--save-dir', str(baseline_dir)]
print('Running baseline:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=repo_root, check=False)
print('returncode', res.returncode)
assert res.returncode == 0, 'baseline training failed'

# %%
import subprocess, sys
prime_dir = repo_root / 'checkpoints' / 'prime_bump'
prime_dir.mkdir(parents=True, exist_ok=True)
cmd = [sys.executable, 'train.py', '--config-preset', 'baseline', '--prime-bump-init', '--prime-bump-scale', '0.02', '--save-dir', str(prime_dir)]
print('Running prime-bump:', ' '.join(cmd))
res = subprocess.run(cmd, cwd=repo_root, check=False)
print('returncode', res.returncode)
assert res.returncode == 0, 'prime-bump training failed'

# %%
import csv, pathlib

def latest_csv(log_dir: pathlib.Path):
    files = sorted(log_dir.glob('*.csv'), key=lambda p: p.stat().st_mtime, reverse=True)
    return files[0] if files else None

def read_last_row(csv_path: pathlib.Path):
    with csv_path.open() as f:
        rows = list(csv.DictReader(f))
    return rows[-1] if rows else None

def summarize(run_name, save_dir: pathlib.Path):
    log_dir = save_dir / 'logs'
    csv_path = latest_csv(log_dir)
    if not csv_path:
        print(f"[{run_name}] no CSV in {log_dir}")
        return None
    last = read_last_row(csv_path)
    if not last:
        print(f"[{run_name}] empty CSV {csv_path}")
        return None
    out = {
        'path': str(csv_path),
        'step': int(last['step']),
        'epoch': int(last['epoch']),
        'loss': float(last['loss']),
        'ppl': float(last['perplexity']),
        'grad_norm': float(last['grad_norm']),
        'nan': int(last.get('num_nan_grads', 0) or 0),
        'inf': int(last.get('num_inf_grads', 0) or 0),
    }
    print(f"[{run_name}] step {out['step']} epoch {out['epoch']} loss {out['loss']:.4f} ppl {out['ppl']:.1f} grad_norm {out['grad_norm']:.3f} nan {out['nan']} inf {out['inf']} ({csv_path.name})")
    return out

baseline_summary = summarize('baseline', baseline_dir)
prime_summary = summarize('prime-bump', prime_dir)

if baseline_summary and prime_summary:
    delta_loss = prime_summary['loss'] - baseline_summary['loss']
    delta_ppl = prime_summary['ppl'] - baseline_summary['ppl']
    print(f"Δloss (prime-baseline): {delta_loss:+.4f}, Δppl: {delta_ppl:+.1f}")
else:
    print('Could not compare; missing summaries.')
